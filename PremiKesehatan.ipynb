# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
# Generaset Dataset Dummy
np.random.seed(42)
n_samples = 5000

umur = np.random.randint(18, 70, size=n_samples)
penghasilan = np.random.randint(3_000_000, 15_000_000, size=n_samples)
merokok = np.random.choice([0, 1], size=n_samples)
bmi = np.round(np.random.normal(25, 5, size=n_samples), 1)
penyakit_kronis = np.random.choice([0, 1], size=n_samples)

# %%
# Gabung ke DataFrame
df = pd.DataFrame({
    'Umur': umur,
    'Penghasilan': penghasilan,
    'Merokok': merokok,
    'BMI': bmi,
    'Penyakit Kronis': penyakit_kronis
})
df
# Out:
#       Umur  Penghasilan  Merokok   BMI  Penyakit Kronis
# 0       56      5361216        1  28.3                1
# 1       69     10446153        0  28.9                1
# 2       46      5567587        1  33.3                0
# 3       32      3264237        1  22.9                1
# 4       60      7469353        1  30.0                0
# ...    ...          ...      ...   ...              ...
# 4995    24      7949331        0  26.3                0
# 4996    66      8280156        0  22.1                1
# 4997    26     13802519        0  24.8                1
# 4998    53     11399122        1  23.5                0
# 4999    36      5144608        1  30.0                0
#
# [5000 rows x 5 columns]

# %%
# Membuat Label Risiko dan Premi
risk_score = (
    (umur > 50).astype(int) +
    (bmi > 30).astype(int) +
    merokok +
    penyakit_kronis
)
risk_label = pd.cut(risk_score, bins=[-1, 1, 2, 4], labels=[0, 1, 2]).astype(int)

base_premi = 100_000
premi = base_premi + (risk_label * 100_000) + (penghasilan * 0.01)
premi = premi.astype(int)

# %%
#  Membuat DataFrame dan Membagi Data
df = pd.DataFrame({
    'umur': umur,
    'penghasilan': penghasilan,
    'merokok': merokok,
    'bmi': bmi,
    'penyakit_kronis': penyakit_kronis,
    'risk_label': risk_label,
    'premi': premi
})


features = df[['umur', 'penghasilan', 'merokok', 'bmi', 'penyakit_kronis']]
target_risk = df['risk_label']
target_premi = df['premi']

X_train, X_test, y_risk_train, y_risk_test, y_premi_train, y_premi_test = train_test_split(
    features, target_risk, target_premi, test_size=0.2, random_state=42
)

# %%
# Standarisasi Fitur Numerik
scaler = StandardScaler()
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

X_train_scaled[['umur', 'penghasilan', 'bmi']] = scaler.fit_transform(X_train[['umur', 'penghasilan', 'bmi']])
X_test_scaled[['umur', 'penghasilan', 'bmi']] = scaler.transform(X_test[['umur', 'penghasilan', 'bmi']])

# %%
# Membangun Model TensorFlow
input_layer = tf.keras.Input(shape=(5,))

x = tf.keras.layers.Dense(64, activation='relu')(input_layer)
x = tf.keras.layers.Dense(32, activation='relu')(x)

risk_output = tf.keras.layers.Dense(3, activation='softmax', name='risk_label')(x)
premi_output = tf.keras.layers.Dense(1, activation='linear', name='premi')(x)

model = tf.keras.Model(inputs=input_layer, outputs=[risk_output, premi_output])
model.compile(
    optimizer='adam',
    loss={
        'risk_label': 'sparse_categorical_crossentropy',  # klasifikasi multi kelas
        'premi': 'mse'  # regresi nilai kontinu
    },
    metrics={
        'risk_label': 'accuracy',
        'premi': 'mae'  # mean absolute error, supaya mudah dimengerti error-nya
    }
)

# %%
# Melatih Model
history = model.fit(
    X_train_scaled,
    {'risk_label': y_risk_train, 'premi': y_premi_train},
    validation_data=(X_test_scaled, {'risk_label': y_risk_test, 'premi': y_premi_test}),
    epochs=30,
    batch_size=32,
    verbose=2
)
# Out:
# Epoch 1/30
# 125/125 - 2s - 20ms/step - loss: 71859978240.0000 - premi_loss: 71859978240.0000 - premi_mae: 255667.3750 - risk_label_accuracy: 0.3970 - risk_label_loss: 1.1211 - val_loss: 71007821824.0000 - val_premi_loss: 71213383680.0000 - val_premi_mae: 253760.6094 - val_risk_label_accuracy: 0.4490 - val_risk_label_loss: 1.1048
# Epoch 2/30
# 125/125 - 0s - 3ms/step - loss: 71810334720.0000 - premi_loss: 71810334720.0000 - premi_mae: 255578.1719 - risk_label_accuracy: 0.4420 - risk_label_loss: 1.1247 - val_loss: 70903480320.0000 - val_premi_loss: 71108927488.0000 - val_premi_mae: 253574.9531 - val_risk_label_accuracy: 0.4670 - val_risk_label_loss: 1.1285
# Epoch 3/30
# 125/125 - 0s - 3ms/step - loss: 71608442880.0000 - premi_loss: 71608442880.0000 - premi_mae: 255224.0625 - risk_label_accuracy: 0.4383 - risk_label_loss: 1.1818 - val_loss: 70588948480.0000 - val_premi_loss: 70793961472.0000 - val_premi_mae: 253026.2500 - val_risk_label_accuracy: 0.4090 - val_risk_label_loss: 1.2083
# Epoch 4/30
# 125/125 - 0s - 3ms/step - loss: 71139835904.0000 - premi_loss: 71139835904.0000 - premi_mae: 254411.0156 - risk_label_accuracy: 0.4300 - risk_label_loss: 1.3509 - val_loss: 69965242368.0000 - val_premi_loss: 70169354240.0000 - val_premi_mae: 251945.2500 - val_risk_label_accuracy: 0.4460 - val_risk_label_loss: 1.1618
# Epoch 5/30
# 125/125 - 0s - 3ms/step - loss: 70310789120.0000 - premi_loss: 70310789120.0000 - premi_mae: 252979.0156 - risk_label_accuracy: 0.4238 - risk_label_loss: 1.6004 - val_loss: 68942258176.0000 - val_premi_loss: 69144788992.0000 - val_premi_mae: 250172.1406 - val_risk_label_accuracy: 0.4120 - val_risk_label_loss: 2.4138
# Epoch 6/30
# 125/125 - 0s - 3ms/step - loss: 69052440576.0000 - premi_loss: 69052440576.0000 - premi_mae: 250782.9844 - risk_label_accuracy: 0.4478 - risk_label_loss: 1.4943 - val_loss: 67468820480.0000 - val_premi_loss: 67669041152.0000 - val_premi_mae: 247602.7969 - val_risk_label_accuracy: 0.4830 - val_risk_label_loss: 1.2036
# Epoch 7/30
# 125/125 - 0s - 3ms/step - loss: 67309371392.0000 - premi_loss: 67309371392.0000 - premi_mae: 247739.5156 - risk_label_accuracy: 0.4385 - risk_label_loss: 1.5655 - val_loss: 65514381312.0000 - val_premi_loss: 65711534080.0000 - val_premi_mae: 244153.6875 - val_risk_label_accuracy: 0.4580 - val_risk_label_loss: 1.2243
# Epoch 8/30
# 125/125 - 0s - 3ms/step - loss: 65059778560.0000 - premi_loss: 65059778560.0000 - premi_mae: 243732.0781 - risk_label_accuracy: 0.4507 - risk_label_loss: 1.5242 - val_loss: 63032729600.0000 - val_premi_loss: 63225729024.0000 - val_premi_mae: 239703.0156 - val_risk_label_accuracy: 0.4790 - val_risk_label_loss: 1.4113
# Epoch 9/30
# 125/125 - 0s - 3ms/step - loss: 62295105536.0000 - premi_loss: 62295105536.0000 - premi_mae: 238725.4844 - risk_label_accuracy: 0.4338 - risk_label_loss: 2.2366 - val_loss: 60075831296.0000 - val_premi_loss: 60263923712.0000 - val_premi_mae: 234275.8906 - val_risk_label_accuracy: 0.4880 - val_risk_label_loss: 1.5258
# Epoch 10/30
# 125/125 - 0s - 3ms/step - loss: 59041140736.0000 - premi_loss: 59041140736.0000 - premi_mae: 232669.0312 - risk_label_accuracy: 0.4310 - risk_label_loss: 2.2847 - val_loss: 56641871872.0000 - val_premi_loss: 56823742464.0000 - val_premi_mae: 227792.3906 - val_risk_label_accuracy: 0.4970 - val_risk_label_loss: 2.0416
# Epoch 11/30
# 125/125 - 0s - 3ms/step - loss: 55351660544.0000 - premi_loss: 55351660544.0000 - premi_mae: 225561.3750 - risk_label_accuracy: 0.4400 - risk_label_loss: 2.3016 - val_loss: 52824412160.0000 - val_premi_loss: 52999499776.0000 - val_premi_mae: 220310.3750 - val_risk_label_accuracy: 0.5060 - val_risk_label_loss: 1.7120
# Epoch 12/30
# 125/125 - 0s - 4ms/step - loss: 51290660864.0000 - premi_loss: 51290660864.0000 - premi_mae: 217462.4844 - risk_label_accuracy: 0.4375 - risk_label_loss: 2.5777 - val_loss: 48652840960.0000 - val_premi_loss: 48819929088.0000 - val_premi_mae: 211788.3594 - val_risk_label_accuracy: 0.2940 - val_risk_label_loss: 2.8844
# Epoch 13/30
# 125/125 - 0s - 4ms/step - loss: 46931214336.0000 - premi_loss: 46931214336.0000 - premi_mae: 208337.9219 - risk_label_accuracy: 0.4325 - risk_label_loss: 4.0061 - val_loss: 44290531328.0000 - val_premi_loss: 44449259520.0000 - val_premi_mae: 202412.5000 - val_risk_label_accuracy: 0.4900 - val_risk_label_loss: 4.6896
# Epoch 14/30
# 125/125 - 0s - 4ms/step - loss: 42383331328.0000 - premi_loss: 42383331328.0000 - premi_mae: 198269.7500 - risk_label_accuracy: 0.4132 - risk_label_loss: 4.1482 - val_loss: 39722733568.0000 - val_premi_loss: 39871746048.0000 - val_premi_mae: 192016.1562 - val_risk_label_accuracy: 0.2950 - val_risk_label_loss: 4.6533
# Epoch 15/30
# 125/125 - 0s - 3ms/step - loss: 37743828992.0000 - premi_loss: 37743828992.0000 - premi_mae: 187336.8750 - risk_label_accuracy: 0.4288 - risk_label_loss: 3.7108 - val_loss: 35151187968.0000 - val_premi_loss: 35290226688.0000 - val_premi_mae: 180882.1406 - val_risk_label_accuracy: 0.4410 - val_risk_label_loss: 5.5235
# Epoch 16/30
# 125/125 - 0s - 3ms/step - loss: 33131386880.0000 - premi_loss: 33131386880.0000 - premi_mae: 175664.4375 - risk_label_accuracy: 0.4232 - risk_label_loss: 5.5975 - val_loss: 30661916672.0000 - val_premi_loss: 30790617088.0000 - val_premi_mae: 169080.4688 - val_risk_label_accuracy: 0.3980 - val_risk_label_loss: 6.8936
# Epoch 17/30
# 125/125 - 0s - 3ms/step - loss: 28651735040.0000 - premi_loss: 28651735040.0000 - premi_mae: 163350.7344 - risk_label_accuracy: 0.4317 - risk_label_loss: 5.4586 - val_loss: 26354278400.0000 - val_premi_loss: 26472476672.0000 - val_premi_mae: 156732.3750 - val_risk_label_accuracy: 0.3130 - val_risk_label_loss: 5.8031
# Epoch 18/30
# 125/125 - 0s - 3ms/step - loss: 24409536512.0000 - premi_loss: 24409536512.0000 - premi_mae: 150606.1562 - risk_label_accuracy: 0.4187 - risk_label_loss: 9.2849 - val_loss: 22319941632.0000 - val_premi_loss: 22427322368.0000 - val_premi_mae: 143991.8750 - val_risk_label_accuracy: 0.4110 - val_risk_label_loss: 5.8313
# Epoch 19/30
# 125/125 - 0s - 3ms/step - loss: 20493858816.0000 - premi_loss: 20493858816.0000 - premi_mae: 137525.8594 - risk_label_accuracy: 0.4157 - risk_label_loss: 5.7369 - val_loss: 18636570624.0000 - val_premi_loss: 18733211648.0000 - val_premi_mae: 131024.6406 - val_risk_label_accuracy: 0.3240 - val_risk_label_loss: 8.5033
# Epoch 20/30
# 125/125 - 0s - 3ms/step - loss: 16969622528.0000 - premi_loss: 16969622528.0000 - premi_mae: 124341.9062 - risk_label_accuracy: 0.4062 - risk_label_loss: 7.4547 - val_loss: 15373618176.0000 - val_premi_loss: 15459624960.0000 - val_premi_mae: 118065.8047 - val_risk_label_accuracy: 0.4100 - val_risk_label_loss: 10.3045
# Epoch 21/30
# 125/125 - 0s - 3ms/step - loss: 13886587904.0000 - premi_loss: 13886587904.0000 - premi_mae: 111264.0859 - risk_label_accuracy: 0.4187 - risk_label_loss: 7.4340 - val_loss: 12550423552.0000 - val_premi_loss: 12626251776.0000 - val_premi_mae: 105266.0938 - val_risk_label_accuracy: 0.4960 - val_risk_label_loss: 4.8773
# Epoch 22/30
# 125/125 - 0s - 3ms/step - loss: 11264808960.0000 - premi_loss: 11264808960.0000 - premi_mae: 98523.8984 - risk_label_accuracy: 0.4365 - risk_label_loss: 6.1372 - val_loss: 10178769920.0000 - val_premi_loss: 10244924416.0000 - val_premi_mae: 92932.3203 - val_risk_label_accuracy: 0.3960 - val_risk_label_loss: 9.8489
# Epoch 23/30
# 125/125 - 0s - 3ms/step - loss: 9099314176.0000 - premi_loss: 9099314176.0000 - premi_mae: 86449.2031 - risk_label_accuracy: 0.4162 - risk_label_loss: 8.8096 - val_loss: 8254873600.0000 - val_premi_loss: 8311875072.0000 - val_premi_mae: 81478.3047 - val_risk_label_accuracy: 0.5110 - val_risk_label_loss: 19.2480
# Epoch 24/30
# 125/125 - 0s - 3ms/step - loss: 7365917696.0000 - premi_loss: 7365917696.0000 - premi_mae: 75518.0859 - risk_label_accuracy: 0.4025 - risk_label_loss: 7.4801 - val_loss: 6733967872.0000 - val_premi_loss: 6782874112.0000 - val_premi_mae: 71257.2188 - val_risk_label_accuracy: 0.4550 - val_risk_label_loss: 1.2332
# Epoch 25/30
# 125/125 - 1s - 4ms/step - loss: 6020483584.0000 - premi_loss: 6020483584.0000 - premi_mae: 66145.2109 - risk_label_accuracy: 0.4227 - risk_label_loss: 5.2033 - val_loss: 5567271936.0000 - val_premi_loss: 5608692736.0000 - val_premi_mae: 62588.1445 - val_risk_label_accuracy: 0.3390 - val_risk_label_loss: 3.2815
# Epoch 26/30
# 125/125 - 0s - 3ms/step - loss: 5007138816.0000 - premi_loss: 5007138816.0000 - premi_mae: 58526.0898 - risk_label_accuracy: 0.4218 - risk_label_loss: 6.3505 - val_loss: 4702533632.0000 - val_premi_loss: 4737354240.0000 - val_premi_mae: 55886.3906 - val_risk_label_accuracy: 0.5180 - val_risk_label_loss: 4.3588
# Epoch 27/30
# 125/125 - 0s - 3ms/step - loss: 4267673600.0000 - premi_loss: 4267673600.0000 - premi_mae: 52808.7188 - risk_label_accuracy: 0.4098 - risk_label_loss: 8.7985 - val_loss: 4069842176.0000 - val_premi_loss: 4098786048.0000 - val_premi_mae: 50991.3086 - val_risk_label_accuracy: 0.3710 - val_risk_label_loss: 10.2449
# Epoch 28/30
# 125/125 - 0s - 3ms/step - loss: 3740237568.0000 - premi_loss: 3740237568.0000 - premi_mae: 48660.5898 - risk_label_accuracy: 0.4145 - risk_label_loss: 8.8877 - val_loss: 3627612672.0000 - val_premi_loss: 3651688192.0000 - val_premi_mae: 47638.0898 - val_risk_label_accuracy: 0.4440 - val_risk_label_loss: 14.2560
# Epoch 29/30
# 125/125 - 0s - 3ms/step - loss: 3371796992.0000 - premi_loss: 3371796992.0000 - premi_mae: 45767.7422 - risk_label_accuracy: 0.4050 - risk_label_loss: 8.8399 - val_loss: 3318323968.0000 - val_premi_loss: 3338306816.0000 - val_premi_mae: 45431.9961 - val_risk_label_accuracy: 0.5210 - val_risk_label_loss: 5.4558
# Epoch 30/30
# 125/125 - 0s - 3ms/step - loss: 3118139648.0000 - premi_loss: 3118139648.0000 - premi_mae: 43856.4102 - risk_label_accuracy: 0.4005 - risk_label_loss: 9.6292 - val_loss: 3100734208.0000 - val_premi_loss: 3117381888.0000 - val_premi_mae: 43909.3711 - val_risk_label_accuracy: 0.5110 - val_risk_label_loss: 6.5766

# %%
# Evaluasi Model
eval_results = model.evaluate(X_test_scaled, {'risk_label': y_risk_test, 'premi': y_premi_test}, verbose=2)
print(f"Test Loss dan Metrics: {eval_results}")
# Out:
# 32/32 - 0s - 3ms/step - loss: 3100734208.0000 - premi_loss: 3117381888.0000 - premi_mae: 43909.3711 - risk_label_accuracy: 0.5110 - risk_label_loss: 6.5766
# Test Loss dan Metrics: [3100734208.0, 6.576597213745117, 3117381888.0, 43909.37109375, 0.5109999775886536]

# %%
# Menyimpan Model
model.save('model_asuransi_kesehatan.h5')

import joblib
joblib.dump(scaler, 'scaler_asuransi_kesehatan.pkl')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['scaler_asuransi_kesehatan.pkl']

# %%
# Load Model dan Scaler untuk Prediksi

from tensorflow.keras.models import load_model
import joblib

# Load model dan scaler
model = load_model('model_asuransi_kesehatan.h5', compile=False)

scaler = joblib.load('scaler_asuransi_kesehatan.pkl')

# Fungsi prediksi risiko dan premi baru
def prediksi_risiko_premi(umur, penghasilan, merokok, bmi, penyakit_kronis, base_premi=100_000):
    input_df = pd.DataFrame({
        'umur': [umur],
        'penghasilan': [penghasilan],
        'merokok': [1 if merokok else 0],
        'bmi': [bmi],
        'penyakit_kronis': [1 if penyakit_kronis else 0]
    })
    
    # Standarisasi fitur numerik
    input_scaled = input_df.copy()
    input_scaled[['umur','penghasilan','bmi']] = scaler.transform(input_df[['umur','penghasilan','bmi']])
    
    # Prediksi
    prediksi = model.predict(input_scaled)
    kelas_risiko = np.argmax(prediksi[0], axis=1)[0]
    
    # Hitung premi akhir
    premi_final = base_premi + (kelas_risiko * 100_000) + (penghasilan * 0.01)
    
    return kelas_risiko, int(premi_final)

# %%
# Contoh input user
umur = 18
penghasilan = 9000000
merokok = True
bmi = 28
penyakit_kronis = False

kelas_risiko, premi = prediksi_risiko_premi(umur, penghasilan, merokok, bmi, penyakit_kronis)

print(f'Kelas Risiko: {kelas_risiko}')   # 0 = rendah, 1 = sedang, 2 = tinggi (sesuai label)
print(f'Perkiraan Premi: Rp {premi}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Kelas Risiko: 0
# Perkiraan Premi: Rp 190000
