# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('AsuransiKesehatan.csv')

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice
# 0                         0         25000
# 1                         0         29000
# 2                         1         23000
# 3                         2         28000
# 4                         1         23000
# ..                      ...           ...
# 981                       0         15000
# 982                       3         28000
# 983                       1         29000
# 984                       1         39000
# 985                       1         15000
#
# [986 rows x 11 columns]

# %%
df.rename(columns={
    "Age": "Usia",
    "Diabetes": "Diabetes",
    "BloodPressureProblems": "Masalah Tekanan Darah",
    "AnyTransplants": "Riwayat Transplantasi",
    "AnyChronicDiseases": "Penyakit Kronis",
    "Height": "Tinggi Badan cm",
    "Weight": "Berat Badan kg",
    "KnownAllergies": "Alergi",
    "HistoryOfCancerInFamily": "Riwayat Kanker Keluarga",
    "NumberOfMajorSurgeries": "Jumlah Operasi Besar",
    "PremiumPrice": "Premi Asuransi"
}, inplace=True)

df["Premi Asuransi"] = df["Premi Asuransi"] * 12
df
# Out:
#      Usia  Diabetes  Masalah Tekanan Darah  Riwayat Transplantasi  \
# 0      45         0                      0                      0
# 1      60         1                      0                      0
# 2      36         1                      1                      0
# 3      52         1                      1                      0
# 4      38         0                      0                      0
# ..    ...       ...                    ...                    ...
# 981    18         0                      0                      0
# 982    64         1                      1                      0
# 983    56         0                      1                      0
# 984    47         1                      1                      0
# 985    21         0                      0                      0
#
#      Penyakit Kronis  Tinggi Badan cm  Berat Badan kg  Alergi  \
# 0                  0              155              57       0
# 1                  0              180              73       0
# 2                  0              158              59       0
# 3                  1              183              93       0
# 4                  1              166              88       0
# ..               ...              ...             ...     ...
# 981                0              169              67       0
# 982                0              153              70       0
# 983                0              155              71       0
# 984                0              158              73       1
# 985                0              158              75       1
#
#      Riwayat Kanker Keluarga  Jumlah Operasi Besar  Premi Asuransi
# 0                          0                     0          300000
# 1                          0                     0          348000
# 2                          0                     1          276000
# 3                          0                     2          336000
# 4                          0                     1          276000
# ..                       ...                   ...             ...
# 981                        0                     0          180000
# 982                        0                     3          336000
# 983                        0                     1          348000
# 984                        0                     1          468000
# 985                        0                     1          180000
#
# [986 rows x 11 columns]

# %%
def buat_label_risiko(premi):
    if premi < 2000000:
        return 0  # risiko rendah
    elif premi < 4000000:
        return 1  # risiko sedang
    else:
        return 2  # risiko tinggi

df['Risiko'] = df['Premi Asuransi'].apply(buat_label_risiko)
df
# Out:
#      Usia  Diabetes  Masalah Tekanan Darah  Riwayat Transplantasi  \
# 0      45         0                      0                      0
# 1      60         1                      0                      0
# 2      36         1                      1                      0
# 3      52         1                      1                      0
# 4      38         0                      0                      0
# ..    ...       ...                    ...                    ...
# 981    18         0                      0                      0
# 982    64         1                      1                      0
# 983    56         0                      1                      0
# 984    47         1                      1                      0
# 985    21         0                      0                      0
#
#      Penyakit Kronis  Tinggi Badan cm  Berat Badan kg  Alergi  \
# 0                  0              155              57       0
# 1                  0              180              73       0
# 2                  0              158              59       0
# 3                  1              183              93       0
# 4                  1              166              88       0
# ..               ...              ...             ...     ...
# 981                0              169              67       0
# 982                0              153              70       0
# 983                0              155              71       0
# 984                0              158              73       1
# 985                0              158              75       1
#
#      Riwayat Kanker Keluarga  Jumlah Operasi Besar  Premi Asuransi  Risiko
# 0                          0                     0          300000       0
# 1                          0                     0          348000       0
# 2                          0                     1          276000       0
# 3                          0                     2          336000       0
# 4                          0                     1          276000       0
# ..                       ...                   ...             ...     ...
# 981                        0                     0          180000       0
# 982                        0                     3          336000       0
# 983                        0                     1          348000       0
# 984                        0                     1          468000       0
# 985                        0                     1          180000       0
#
# [986 rows x 12 columns]

# %%
X = df.drop(['Premi Asuransi', 'Risiko'], axis=1).values
y_reg = df['Premi Asuransi'].values
y_clf = df['Risiko'].values

# %%
from sklearn.preprocessing import StandardScaler

scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

scaler_y_reg = StandardScaler()
y_reg_scaled = scaler_y_reg.fit_transform(y_reg.reshape(-1,1))

# %%
X_train, X_test, y_train_reg, y_test_reg, y_train_clf, y_test_clf = train_test_split(
    X_scaled, y_reg_scaled.flatten(), y_clf, test_size=0.2, random_state=42
)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import keras_tuner as kt

def build_model(hp):
    inputs = layers.Input(shape=(X_train.shape[1],))
    x = layers.Dense(units=hp.Int('units', 64, 128, step=32), activation='relu')(inputs)
    x = layers.Dropout(rate=hp.Float('dropout', 0.2, 0.4, step=0.1))(x)
    
    risk_output = layers.Dense(3, activation='softmax', name='risk_output')(x)
    premium_output = layers.Dense(1, activation='linear', name='premium_output')(x)

    model = models.Model(inputs=inputs, outputs=[risk_output, premium_output])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=hp.Float('lr', 1e-4, 1e-3, sampling='log')
        ),
        loss={
            'risk_output': 'sparse_categorical_crossentropy',
            'premium_output': 'mse'
        },
        metrics={
            'risk_output': 'accuracy',
            'premium_output': 'mae'
        }
    )
    return model

# %%
from keras_tuner import Objective

tuner = kt.RandomSearch(
    build_model,
    objective=Objective("val_risk_output_accuracy", direction="max"),  # ← tambahkan direction
    max_trials=10,
    executions_per_trial=1,
    directory='asuransi_tuning',
    project_name='multioutput_model'
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)
# Out:
# Reloading Tuner from asuransi_tuning\multioutput_model\tuner0.json

# %%
tuner.search(
    X_train,
    {'risk_output': y_train_clf, 'premium_output': y_train_reg},
    validation_data=(X_test, {'risk_output': y_test_clf, 'premium_output': y_test_reg}),
    epochs=50,
    batch_size=64,
    callbacks=[early_stop],
    verbose=2
)

# %%
# Ambil hyperparameter terbaik
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build model dengan hyperparameter terbaik
best_model = build_model(best_hp)

# Latih model terbaik dengan data training (optional, tapi direkomendasikan)
best_model.fit(
    X_train,
    {'risk_output': y_train_clf, 'premium_output': y_train_reg},
    validation_data=(X_test, {'risk_output': y_test_clf, 'premium_output': y_test_reg}),
    epochs=50,
    batch_size=64,
    callbacks=[early_stop],
    verbose=2
)
# Out:
# Epoch 1/50
# 13/13 - 2s - 151ms/step - loss: 2.0005 - premium_output_loss: 1.0677 - premium_output_mae: 0.7455 - risk_output_accuracy: 0.6485 - risk_output_loss: 0.9085 - val_loss: 1.6870 - val_premium_output_loss: 0.9630 - val_premium_output_mae: 0.7185 - val_risk_output_accuracy: 0.9293 - val_risk_output_loss: 0.7138
# Epoch 2/50
# 13/13 - 0s - 20ms/step - loss: 1.5077 - premium_output_loss: 0.8819 - premium_output_mae: 0.6749 - risk_output_accuracy: 0.9137 - risk_output_loss: 0.6114 - val_loss: 1.2386 - val_premium_output_loss: 0.7513 - val_premium_output_mae: 0.6431 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.4808
# Epoch 3/50
# 13/13 - 0s - 14ms/step - loss: 1.1625 - premium_output_loss: 0.7590 - premium_output_mae: 0.6238 - risk_output_accuracy: 0.9962 - risk_output_loss: 0.4091 - val_loss: 0.9484 - val_premium_output_loss: 0.6167 - val_premium_output_mae: 0.5926 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.3299
# Epoch 4/50
# 13/13 - 0s - 16ms/step - loss: 0.9285 - premium_output_loss: 0.6337 - premium_output_mae: 0.5789 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.2880 - val_loss: 0.7605 - val_premium_output_loss: 0.5292 - val_premium_output_mae: 0.5513 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.2348
# Epoch 5/50
# 13/13 - 0s - 13ms/step - loss: 0.7571 - premium_output_loss: 0.5494 - premium_output_mae: 0.5474 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.2108 - val_loss: 0.6324 - val_premium_output_loss: 0.4667 - val_premium_output_mae: 0.5132 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.1736
# Epoch 6/50
# 13/13 - 0s - 12ms/step - loss: 0.6621 - premium_output_loss: 0.4989 - premium_output_mae: 0.5265 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.1567 - val_loss: 0.5386 - val_premium_output_loss: 0.4107 - val_premium_output_mae: 0.4793 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.1337
# Epoch 7/50
# 13/13 - 0s - 12ms/step - loss: 0.5705 - premium_output_loss: 0.4479 - premium_output_mae: 0.4975 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.1190 - val_loss: 0.4761 - val_premium_output_loss: 0.3676 - val_premium_output_mae: 0.4546 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.1059
# Epoch 8/50
# 13/13 - 0s - 12ms/step - loss: 0.5074 - premium_output_loss: 0.4170 - premium_output_mae: 0.4658 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0977 - val_loss: 0.4335 - val_premium_output_loss: 0.3401 - val_premium_output_mae: 0.4343 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0863
# Epoch 9/50
# 13/13 - 0s - 12ms/step - loss: 0.5112 - premium_output_loss: 0.4152 - premium_output_mae: 0.4744 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0837 - val_loss: 0.4083 - val_premium_output_loss: 0.3276 - val_premium_output_mae: 0.4246 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0717
# Epoch 10/50
# 13/13 - 0s - 12ms/step - loss: 0.4622 - premium_output_loss: 0.3818 - premium_output_mae: 0.4465 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0676 - val_loss: 0.3869 - val_premium_output_loss: 0.3143 - val_premium_output_mae: 0.4173 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0606
# Epoch 11/50
# 13/13 - 0s - 12ms/step - loss: 0.4482 - premium_output_loss: 0.4023 - premium_output_mae: 0.4410 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0564 - val_loss: 0.3675 - val_premium_output_loss: 0.2945 - val_premium_output_mae: 0.4111 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0521
# Epoch 12/50
# 13/13 - 0s - 12ms/step - loss: 0.4550 - premium_output_loss: 0.3939 - premium_output_mae: 0.4507 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0546 - val_loss: 0.3523 - val_premium_output_loss: 0.2822 - val_premium_output_mae: 0.4037 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0451
# Epoch 13/50
# 13/13 - 0s - 14ms/step - loss: 0.4367 - premium_output_loss: 0.3790 - premium_output_mae: 0.4449 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0459 - val_loss: 0.3489 - val_premium_output_loss: 0.2846 - val_premium_output_mae: 0.4022 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0396
# Epoch 14/50
# 13/13 - 0s - 15ms/step - loss: 0.4317 - premium_output_loss: 0.3875 - premium_output_mae: 0.4496 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0403 - val_loss: 0.3397 - val_premium_output_loss: 0.2732 - val_premium_output_mae: 0.4003 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0351
# Epoch 15/50
# 13/13 - 0s - 14ms/step - loss: 0.4054 - premium_output_loss: 0.3608 - premium_output_mae: 0.4382 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0362 - val_loss: 0.3344 - val_premium_output_loss: 0.2696 - val_premium_output_mae: 0.3980 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0314
# Epoch 16/50
# 13/13 - 0s - 14ms/step - loss: 0.3938 - premium_output_loss: 0.3595 - premium_output_mae: 0.4183 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0319 - val_loss: 0.3278 - val_premium_output_loss: 0.2612 - val_premium_output_mae: 0.3955 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0282
# Epoch 17/50
# 13/13 - 0s - 14ms/step - loss: 0.4189 - premium_output_loss: 0.3851 - premium_output_mae: 0.4393 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0290 - val_loss: 0.3244 - val_premium_output_loss: 0.2571 - val_premium_output_mae: 0.3939 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0256
# Epoch 18/50
# 13/13 - 0s - 14ms/step - loss: 0.3822 - premium_output_loss: 0.3473 - premium_output_mae: 0.4211 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0265 - val_loss: 0.3265 - val_premium_output_loss: 0.2677 - val_premium_output_mae: 0.3964 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0235
# Epoch 19/50
# 13/13 - 0s - 14ms/step - loss: 0.3817 - premium_output_loss: 0.3561 - premium_output_mae: 0.4188 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0244 - val_loss: 0.3246 - val_premium_output_loss: 0.2682 - val_premium_output_mae: 0.3979 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0217
# Epoch 20/50
# 13/13 - 0s - 12ms/step - loss: 0.3977 - premium_output_loss: 0.3768 - premium_output_mae: 0.4306 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0235 - val_loss: 0.3177 - val_premium_output_loss: 0.2590 - val_premium_output_mae: 0.3936 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0199
# Epoch 21/50
# 13/13 - 0s - 13ms/step - loss: 0.3608 - premium_output_loss: 0.3390 - premium_output_mae: 0.4074 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0217 - val_loss: 0.3132 - val_premium_output_loss: 0.2537 - val_premium_output_mae: 0.3902 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0183
# Epoch 22/50
# 13/13 - 0s - 23ms/step - loss: 0.3823 - premium_output_loss: 0.3750 - premium_output_mae: 0.4230 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0197 - val_loss: 0.3120 - val_premium_output_loss: 0.2507 - val_premium_output_mae: 0.3924 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0170
# Epoch 23/50
# 13/13 - 0s - 15ms/step - loss: 0.3595 - premium_output_loss: 0.3409 - premium_output_mae: 0.4190 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0189 - val_loss: 0.3127 - val_premium_output_loss: 0.2530 - val_premium_output_mae: 0.3928 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0158
# Epoch 24/50
# 13/13 - 0s - 13ms/step - loss: 0.3573 - premium_output_loss: 0.3298 - premium_output_mae: 0.4063 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0165 - val_loss: 0.3107 - val_premium_output_loss: 0.2531 - val_premium_output_mae: 0.3916 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0148
# Epoch 25/50
# 13/13 - 0s - 14ms/step - loss: 0.3683 - premium_output_loss: 0.3583 - premium_output_mae: 0.4135 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0158 - val_loss: 0.3078 - val_premium_output_loss: 0.2509 - val_premium_output_mae: 0.3900 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0139
# Epoch 26/50
# 13/13 - 0s - 13ms/step - loss: 0.3724 - premium_output_loss: 0.3508 - premium_output_mae: 0.4196 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0145 - val_loss: 0.3080 - val_premium_output_loss: 0.2512 - val_premium_output_mae: 0.3873 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0130
# Epoch 27/50
# 13/13 - 0s - 14ms/step - loss: 0.3833 - premium_output_loss: 0.3571 - premium_output_mae: 0.4116 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0142 - val_loss: 0.3057 - val_premium_output_loss: 0.2474 - val_premium_output_mae: 0.3907 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0123
# Epoch 28/50
# 13/13 - 0s - 14ms/step - loss: 0.3482 - premium_output_loss: 0.3248 - premium_output_mae: 0.4085 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0133 - val_loss: 0.3019 - val_premium_output_loss: 0.2463 - val_premium_output_mae: 0.3875 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0116
# Epoch 29/50
# 13/13 - 0s - 13ms/step - loss: 0.3514 - premium_output_loss: 0.3608 - premium_output_mae: 0.4065 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0128 - val_loss: 0.3011 - val_premium_output_loss: 0.2464 - val_premium_output_mae: 0.3877 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0110
# Epoch 30/50
# 13/13 - 0s - 13ms/step - loss: 0.3326 - premium_output_loss: 0.3222 - premium_output_mae: 0.3964 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0112 - val_loss: 0.3020 - val_premium_output_loss: 0.2447 - val_premium_output_mae: 0.3889 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0105
# Epoch 31/50
# 13/13 - 0s - 13ms/step - loss: 0.3577 - premium_output_loss: 0.3425 - premium_output_mae: 0.4161 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0119 - val_loss: 0.3008 - val_premium_output_loss: 0.2436 - val_premium_output_mae: 0.3852 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0099
# Epoch 32/50
# 13/13 - 0s - 12ms/step - loss: 0.3435 - premium_output_loss: 0.3601 - premium_output_mae: 0.3926 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0106 - val_loss: 0.2989 - val_premium_output_loss: 0.2408 - val_premium_output_mae: 0.3835 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0095
# Epoch 33/50
# 13/13 - 0s - 16ms/step - loss: 0.3259 - premium_output_loss: 0.3113 - premium_output_mae: 0.3972 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0104 - val_loss: 0.2977 - val_premium_output_loss: 0.2406 - val_premium_output_mae: 0.3818 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0090
# Epoch 34/50
# 13/13 - 0s - 16ms/step - loss: 0.3364 - premium_output_loss: 0.3192 - premium_output_mae: 0.3986 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0101 - val_loss: 0.3001 - val_premium_output_loss: 0.2442 - val_premium_output_mae: 0.3844 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0086
# Epoch 35/50
# 13/13 - 0s - 15ms/step - loss: 0.3293 - premium_output_loss: 0.3274 - premium_output_mae: 0.3931 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0101 - val_loss: 0.2979 - val_premium_output_loss: 0.2410 - val_premium_output_mae: 0.3808 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0082
# Epoch 36/50
# 13/13 - 0s - 13ms/step - loss: 0.3435 - premium_output_loss: 0.3262 - premium_output_mae: 0.4019 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0090 - val_loss: 0.2950 - val_premium_output_loss: 0.2340 - val_premium_output_mae: 0.3799 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0078
# Epoch 37/50
# 13/13 - 0s - 11ms/step - loss: 0.3394 - premium_output_loss: 0.3216 - premium_output_mae: 0.4027 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0088 - val_loss: 0.2974 - val_premium_output_loss: 0.2391 - val_premium_output_mae: 0.3790 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0075
# Epoch 38/50
# 13/13 - 0s - 13ms/step - loss: 0.3264 - premium_output_loss: 0.3113 - premium_output_mae: 0.3898 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0088 - val_loss: 0.2946 - val_premium_output_loss: 0.2376 - val_premium_output_mae: 0.3778 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0072
# Epoch 39/50
# 13/13 - 0s - 12ms/step - loss: 0.3138 - premium_output_loss: 0.3037 - premium_output_mae: 0.3774 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0075 - val_loss: 0.2947 - val_premium_output_loss: 0.2386 - val_premium_output_mae: 0.3817 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0069
# Epoch 40/50
# 13/13 - 0s - 13ms/step - loss: 0.3430 - premium_output_loss: 0.3409 - premium_output_mae: 0.4043 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0080 - val_loss: 0.2953 - val_premium_output_loss: 0.2408 - val_premium_output_mae: 0.3812 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0067
# Epoch 41/50
# 13/13 - 0s - 14ms/step - loss: 0.3483 - premium_output_loss: 0.3457 - premium_output_mae: 0.4097 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0075 - val_loss: 0.2949 - val_premium_output_loss: 0.2402 - val_premium_output_mae: 0.3789 - val_risk_output_accuracy: 1.0000 - val_risk_output_loss: 0.0064

# %%
# Evaluasi model terbaik
results = best_model.evaluate(
    X_test,
    {'risk_output': y_test_clf, 'premium_output': y_test_reg},
    batch_size=128,
    verbose=1
)
print("Evaluasi model terbaik:", results)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3133 - premium_output_loss: 0.2911 - premium_output_mae: 0.3895 - risk_output_accuracy: 1.0000 - risk_output_loss: 0.0067
# Evaluasi model terbaik: [0.294593870639801, 0.006829240825027227, 0.2645323574542999, 0.377778559923172, 1.0]

# %% [markdown]
# - Total loss: 0.295 (gabungan klasifikasi & regresi)
# - Loss regresi (MSE): 0.0068 (sangat kecil)
# - MAE regresi: 0.265 (rata-rata selisih absolut prediksi premi di skala standar)
# - Akurasi klasifikasi risiko: 100% (prediksi kelas risiko sempurna pada data test)
#
# Kesimpulan:
#
# Model sangat baik untuk klasifikasi risiko dan cukup presisi untuk prediksi premi asuransi.

# %%
best_model.save("ModelPremiKesehatan.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import joblib

# Simpan scaler fitur
joblib.dump(scaler_X, "scaler_Kesehatan_X.pkl")

# Simpan scaler target regresi
joblib.dump(scaler_y_reg, "scaler_Kesehatan_Y.pkl")
# Out:
# ['scaler_Kesehatan_Y.pkl']
